# %%
import pandas as pd
import numpy as np

# %%
RAW_PATH = "raw/교통사고통계_raw.csv"

# %%
pd = pd.read_csv(RAW_PATH, encoding="utf-8")

# %%
pd.head()
# Out:
#   사고유형 대분류 사고유형 중분류 사고유형     연도      합계    2020    2021    2022    2023  \
# 0       합계       합계   합계  사고[건]  44,354   8,400   8,889   9,163   8,753
# 1       합계       합계   합계  사망[명]      91      24      23      18      14
# 2       합계       합계   합계  부상[명]  55,096  10,500  10,978  11,389  10,910
# 3     차대사람       합계   합계  사고[건]  12,531   2,082   2,434   2,780   2,627
# 4     차대사람       합계   합계  사망[명]      53      15       9      13      12
#
#      2024
# 0   9,149
# 1      12
# 2  11,319
# 3   2,608
# 4       4
